# %%
import pandas as pd
import piplite
await piplite.install('seaborn')
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("foodhub_order.csv")

# %%
df
# Out:
#       order_id  customer_id                        restaurant_name  \
# 0      1477147       337525                                Hangawi
# 1      1477685       358141              Blue Ribbon Sushi Izakaya
# 2      1477070        66393                            Cafe Habana
# 3      1477334       106968              Blue Ribbon Fried Chicken
# 4      1478249        76942                       Dirty Bird to Go
# ...        ...          ...                                    ...
# 1893   1476701       292602  Chipotle Mexican Grill $1.99 Delivery
# 1894   1477421       397537                              The Smile
# 1895   1477819        35309                      Blue Ribbon Sushi
# 1896   1477513        64151                      Jack's Wife Freda
# 1897   1478056       120353                      Blue Ribbon Sushi
#
#        cuisine_type  cost_of_the_order day_of_the_week     rating  \
# 0            Korean              30.75         Weekend  Not given
# 1          Japanese              12.08         Weekend  Not given
# 2           Mexican              12.23         Weekday          5
# 3          American              29.20         Weekend          3
# 4          American              11.59         Weekday          4
# ...             ...                ...             ...        ...
# 1893        Mexican              22.31         Weekend          5
# 1894       American              12.18         Weekend          5
# 1895       Japanese              25.22         Weekday  Not given
# 1896  Mediterranean              12.18         Weekday          5
# 1897       Japanese              19.45         Weekend  Not given
#
#       food_preparation_time  delivery_time
# 0                        25             20
# 1                        25             23
# 2                        23             28
# 3                        25             15
# 4                        25             24
# ...                     ...            ...
# 1893                     31             17
# 1894                     31             19
# 1895                     31             24
# 1896                     23             31
# 1897                     28             24
#
# [1898 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1898 entries, 0 to 1897
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               1898 non-null   int64
#  1   customer_id            1898 non-null   int64
#  2   restaurant_name        1898 non-null   object
#  3   cuisine_type           1898 non-null   object
#  4   cost_of_the_order      1898 non-null   float64
#  5   day_of_the_week        1898 non-null   object
#  6   rating                 1898 non-null   object
#  7   food_preparation_time  1898 non-null   int64
#  8   delivery_time          1898 non-null   int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 103.9+ KB

# %%
df.shape
# Out:
# (1898, 9)

# %%
df.head(500)
# Out:
#      order_id  customer_id            restaurant_name cuisine_type  \
# 0     1477147       337525                    Hangawi       Korean
# 1     1477685       358141  Blue Ribbon Sushi Izakaya     Japanese
# 2     1477070        66393                Cafe Habana      Mexican
# 3     1477334       106968  Blue Ribbon Fried Chicken     American
# 4     1478249        76942           Dirty Bird to Go     American
# ..        ...          ...                        ...          ...
# 495   1476944       105614             Terakawa Ramen     Japanese
# 496   1477929        87006             Nobu Next Door     Japanese
# 497   1477220        41249          Kambi Ramen House     Japanese
# 498   1476866        42018          Blue Ribbon Sushi     Japanese
# 499   1477037        79215          Blue Ribbon Sushi     Japanese
#
#      cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 0                30.75         Weekend  Not given                     25
# 1                12.08         Weekend  Not given                     25
# 2                12.23         Weekday          5                     23
# 3                29.20         Weekend          3                     25
# 4                11.59         Weekday          4                     25
# ..                 ...             ...        ...                    ...
# 495               8.54         Weekday          3                     27
# 496               6.74         Weekend  Not given                     31
# 497              32.93         Weekend          5                     35
# 498              12.18         Weekday  Not given                     34
# 499              12.23         Weekend          3                     33
#
#      delivery_time
# 0               20
# 1               23
# 2               28
# 3               15
# 4               24
# ..             ...
# 495             25
# 496             29
# 497             19
# 498             32
# 499             21
#
# [500 rows x 9 columns]

# %%
df.tail()
# Out:
#       order_id  customer_id                        restaurant_name  \
# 1893   1476701       292602  Chipotle Mexican Grill $1.99 Delivery
# 1894   1477421       397537                              The Smile
# 1895   1477819        35309                      Blue Ribbon Sushi
# 1896   1477513        64151                      Jack's Wife Freda
# 1897   1478056       120353                      Blue Ribbon Sushi
#
#        cuisine_type  cost_of_the_order day_of_the_week     rating  \
# 1893        Mexican              22.31         Weekend          5
# 1894       American              12.18         Weekend          5
# 1895       Japanese              25.22         Weekday  Not given
# 1896  Mediterranean              12.18         Weekday          5
# 1897       Japanese              19.45         Weekend  Not given
#
#       food_preparation_time  delivery_time
# 1893                     31             17
# 1894                     31             19
# 1895                     31             24
# 1896                     23             31
# 1897                     28             24

# %%
df["order_id"]
# Out:
# 0       1477147
# 1       1477685
# 2       1477070
# 3       1477334
# 4       1478249
#          ...
# 1893    1476701
# 1894    1477421
# 1895    1477819
# 1896    1477513
# 1897    1478056
# Name: order_id, Length: 1898, dtype: int64

# %%
df.iloc[499]
# Out:
# order_id                           1477037
# customer_id                          79215
# restaurant_name          Blue Ribbon Sushi
# cuisine_type                      Japanese
# cost_of_the_order                    12.23
# day_of_the_week                    Weekend
# rating                                   3
# food_preparation_time                   33
# delivery_time                           21
# Name: 499, dtype: object

# %%
df.describe()
# Out:
#            order_id    customer_id  cost_of_the_order  food_preparation_time  \
# count  1.898000e+03    1898.000000        1898.000000            1898.000000
# mean   1.477496e+06  171168.478398          16.498851              27.371970
# std    5.480497e+02  113698.139743           7.483812               4.632481
# min    1.476547e+06    1311.000000           4.470000              20.000000
# 25%    1.477021e+06   77787.750000          12.080000              23.000000
# 50%    1.477496e+06  128600.000000          14.140000              27.000000
# 75%    1.477970e+06  270525.000000          22.297500              31.000000
# max    1.478444e+06  405334.000000          35.410000              35.000000
#
#        delivery_time
# count    1898.000000
# mean       24.161749
# std         4.972637
# min        15.000000
# 25%        20.000000
# 50%        25.000000
# 75%        28.000000
# max        33.000000

# %%
df.isnull().sum()
# Out:
# order_id                 0
# customer_id              0
# restaurant_name          0
# cuisine_type             0
# cost_of_the_order        0
# day_of_the_week          0
# rating                   0
# food_preparation_time    0
# delivery_time            0
# dtype: int64

# %%
df.nunique()
# Out:
# order_id                 1898
# customer_id              1200
# restaurant_name           178
# cuisine_type               14
# cost_of_the_order         312
# day_of_the_week             2
# rating                      4
# food_preparation_time      16
# delivery_time              19
# dtype: int64

# %%
df.sort_values(by = "restaurant_name")
# Out:
#       order_id  customer_id   restaurant_name    cuisine_type  \
# 1877   1478304       321492        'wichcraft        American
# 1583   1476757       115610         12 Chairs  Middle Eastern
# 1457   1477848       276192         12 Chairs  Middle Eastern
# 910    1477681       225912         12 Chairs  Middle Eastern
# 925    1477960       375098         12 Chairs  Middle Eastern
# ...        ...          ...               ...             ...
# 363    1477490       232035  ilili Restaurant  Middle Eastern
# 182    1476875       373353         indikitch          Indian
# 460    1477901       353676         indikitch          Indian
# 601    1478055         7567         indikitch          Indian
# 1069   1477984       353676         indikitch          Indian
#
#       cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 1877               8.10         Weekday          5                     28
# 1583              14.12         Weekend  Not given                     31
# 1457              29.05         Weekday          5                     28
# 910               16.30         Weekday          4                     27
# 925               29.10         Weekend  Not given                     22
# ...                 ...             ...        ...                    ...
# 363                9.17         Weekend  Not given                     26
# 182               22.26         Weekend  Not given                     35
# 460                9.26         Weekend          5                     33
# 601                5.58         Weekend  Not given                     35
# 1069              14.07         Weekend          4                     20
#
#       delivery_time
# 1877             28
# 1583             27
# 1457             32
# 910              26
# 925              26
# ...             ...
# 363              19
# 182              16
# 460              26
# 601              30
# 1069             30
#
# [1898 rows x 9 columns]

# %%
df.groupby('cuisine_type').sum().sort_values(by = "restaurant_name")
# Out:
#                  order_id  customer_id  \
# cuisine_type
# French           26593888      2846497
# Mediterranean    67964240      5331774
# Chinese         317668929     38803384
# American        862853485    107555095
# Japanese        694417840     75902159
# Spanish          17729967      2164002
# Mexican         113763379     13971923
# Middle Eastern   72393190      8273157
# Korean           19206541      2947126
# Southern         25118057      2385782
# Thai             28074933      3853678
# Indian          107857010     11833767
# Italian         440303276     47551355
# Vietnamese       10341724      1458073
#
#                                                   restaurant_name  \
# cuisine_type
# French          Balthazar BoulangerieL'ExpressBalthazar Boulan...
# Mediterranean   BarbouniaPylosJack's Wife FredaMamoun's Falafe...
# Chinese         Big Wong Restaurant _¤¾Ñ¼RedFarm HudsonRedFar...
# American        Blue Ribbon Fried ChickenDirty Bird to GoBlue ...
# Japanese        Blue Ribbon Sushi IzakayaSushi of GariBlue Rib...
# Spanish         BoqueriaBoqueriaSocarrat Paella BarBoqueriaBoq...
# Mexican         Cafe HabanaEmpanada Mama (closed)TortariaChipo...
# Middle Eastern  Cafe MogadorCafe MogadorCafe Mogadorilili Rest...
# Korean          HangawiWoorijipHangawiCho Dang GolDon's Bogam ...
# Southern        Hill Country Fried ChickenHill Country Fried C...
# Thai            KlongPongsri ThaiSong Thai Restaurant & BarPin...
# Indian          Tamarind TriBeCaAnjappar ChettinadBukhara Gril...
# Italian         The Meatball ShopThe Meatball ShopOtto Enoteca...
# Vietnamese      Xe May Sandwich ShopXe May Sandwich ShopV-Nam ...
#
#                 cost_of_the_order  \
# cuisine_type
# French                     356.29
# Mediterranean              711.84
# Chinese                   3505.62
# American                  9530.78
# Japanese                  7663.13
# Spanish                    227.93
# Mexican                   1303.85
# Middle Eastern             922.21
# Korean                     182.02
# Southern                   328.11
# Thai                       364.95
# Indian                    1235.14
# Italian                   4892.77
# Vietnamese                  90.18
#
#                                                   day_of_the_week  \
# cuisine_type
# French          WeekendWeekendWeekendWeekdayWeekendWeekdayWeek...
# Mediterranean   WeekdayWeekendWeekendWeekendWeekendWeekendWeek...
# Chinese         WeekdayWeekendWeekendWeekendWeekdayWeekendWeek...
# American        WeekendWeekdayWeekendWeekdayWeekendWeekendWeek...
# Japanese        WeekendWeekendWeekendWeekendWeekdayWeekendWeek...
# Spanish         WeekendWeekendWeekendWeekdayWeekendWeekendWeek...
# Mexican         WeekdayWeekendWeekendWeekendWeekendWeekendWeek...
# Middle Eastern  WeekdayWeekdayWeekendWeekdayWeekendWeekendWeek...
# Korean          WeekendWeekendWeekendWeekendWeekendWeekendWeek...
# Southern        WeekendWeekendWeekendWeekendWeekendWeekendWeek...
# Thai            WeekendWeekdayWeekendWeekendWeekdayWeekdayWeek...
# Indian          WeekdayWeekdayWeekdayWeekendWeekdayWeekendWeek...
# Italian         WeekendWeekdayWeekendWeekendWeekendWeekdayWeek...
# Vietnamese      WeekendWeekdayWeekendWeekdayWeekdayWeekendWeekend
#
#                                                            rating  \
# cuisine_type
# French          Not given3Not given4Not given55Not givenNot gi...
# Mediterranean   3333555Not given4Not given543344Not given55Not...
# Chinese         Not given45Not given554Not given44Not given5No...
# American        345Not given54Not given5Not givenNot givenNot ...
# Japanese        Not givenNot givenNot given4Not givenNot given...
# Spanish         5Not given5Not givenNot givenNot given45Not gi...
# Mexican         55Not given445Not given5Not given4Not given335...
# Middle Eastern  Not given5Not given44Not givenNot given4Not gi...
# Korean              Not given3Not given4Not given34454Not given55
# Southern        554454Not given5443Not given544Not givenNot given
# Thai            5454Not givenNot givenNot givenNot givenNot gi...
# Indian          35554554Not given4Not given445Not given355Not ...
# Italian         Not given5Not givenNot given545Not givenNot gi...
# Vietnamese                                5Not given5334Not given
#
#                 food_preparation_time  delivery_time
# cuisine_type
# French                            484            456
# Mediterranean                    1242           1085
# Chinese                          5915           5129
# American                        16025          14129
# Japanese                        12930          11342
# Spanish                           323            281
# Mexican                          2058           1878
# Middle Eastern                   1307           1180
# Korean                            331            272
# Southern                          469            405
# Thai                              519            440
# Indian                           1979           1758
# Italian                          8190           7321
# Vietnamese                        180            183

# %%
sns.pointplot(data = df,x = 'rating', y = 'delivery_time')
# Out:
# <Axes: xlabel='rating', ylabel='delivery_time'>

# %%
df
# Out:
#       order_id  customer_id                        restaurant_name  \
# 0      1477147       337525                                Hangawi
# 1      1477685       358141              Blue Ribbon Sushi Izakaya
# 2      1477070        66393                            Cafe Habana
# 3      1477334       106968              Blue Ribbon Fried Chicken
# 4      1478249        76942                       Dirty Bird to Go
# ...        ...          ...                                    ...
# 1893   1476701       292602  Chipotle Mexican Grill $1.99 Delivery
# 1894   1477421       397537                              The Smile
# 1895   1477819        35309                      Blue Ribbon Sushi
# 1896   1477513        64151                      Jack's Wife Freda
# 1897   1478056       120353                      Blue Ribbon Sushi
#
#        cuisine_type  cost_of_the_order day_of_the_week     rating  \
# 0            Korean              30.75         Weekend  Not given
# 1          Japanese              12.08         Weekend  Not given
# 2           Mexican              12.23         Weekday          5
# 3          American              29.20         Weekend          3
# 4          American              11.59         Weekday          4
# ...             ...                ...             ...        ...
# 1893        Mexican              22.31         Weekend          5
# 1894       American              12.18         Weekend          5
# 1895       Japanese              25.22         Weekday  Not given
# 1896  Mediterranean              12.18         Weekday          5
# 1897       Japanese              19.45         Weekend  Not given
#
#       food_preparation_time  delivery_time
# 0                        25             20
# 1                        25             23
# 2                        23             28
# 3                        25             15
# 4                        25             24
# ...                     ...            ...
# 1893                     31             17
# 1894                     31             19
# 1895                     31             24
# 1896                     23             31
# 1897                     28             24
#
# [1898 rows x 9 columns]

# %%
sns.countplot(data = df, x = 'rating');

# %%
plt.figure(figsize=(15, 7))
sns.boxplot(x = 'cuisine_type', y = 'delivery_time', data = df)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.boxplot(data = df, x = 'cuisine_type', y = 'food_preparation_time') 
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize=(15, 7))
sns.pointplot(data = df, x ='rating', y = 'cost_of_the_order')  
plt.show()

# %%
def net_revenue(i):
    if i > 50:
        return i*0.25
    elif i > 40:
        return i*0.15
    else:
        return i*0
df['cost_of_the_order'].apply(net_revenue)
df.head()
# Out:
#    order_id  customer_id            restaurant_name cuisine_type  \
# 0   1477147       337525                    Hangawi       Korean
# 1   1477685       358141  Blue Ribbon Sushi Izakaya     Japanese
# 2   1477070        66393                Cafe Habana      Mexican
# 3   1477334       106968  Blue Ribbon Fried Chicken     American
# 4   1478249        76942           Dirty Bird to Go     American
#
#    cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 0              30.75         Weekend  Not given                     25
# 1              12.08         Weekend  Not given                     25
# 2              12.23         Weekday          5                     23
# 3              29.20         Weekend          3                     25
# 4              11.59         Weekday          4                     25
#
#    delivery_time  revenue   total
# 0             20   4.6125  4.6125
# 1             23   1.8120  1.8120
# 2             28   1.8345  1.8345
# 3             15   4.3800  4.3800
# 4             24   1.7385  1.7385
